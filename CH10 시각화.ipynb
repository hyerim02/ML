# %% [markdown]
# # <span style="color:deepskyblue">1.시각화를 시작하며 </span>
# ---

# %% [markdown]
# # <span style="color:deepskyblue">2.Matplotlib </span>
# ---

# %% [markdown]
# ## <span style="color:lightpink">pyplot 모듈의 이해</span>

# %% [markdown]
# - 직선 그리기

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3],[2,4,6])
plt.title('Hello plot')
plt.show()

# %% [markdown]
# ## <span style="color:lightpink">Figure, Axes 이해</span>

# %% [markdown]
# Figure: 그림판 크기 조절
# Axes: 실제 그림 그리는 method를 가짐 (범례, 타이틀, X축, Y축 등등)

# %% [markdown]
# ## <span style="color:lightpink">Figure, Axes 활용</span>

# %%
plt.figure(figsize=(10,4))
plt.plot([1,2,3],[2,4,6])
plt.title('Hello plot')
plt.show()

# %%
plt.figure(figsize=(4,4),facecolor='skyblue')
plt.plot([1,2,3],[2,4,6])
plt.title('Hello plot')
plt.show()

# %%
fig,ax=plt.subplots(figsize=(4,4))
plt.plot([1,2,3],[2,4,6])
plt.title('Hello plot')
plt.show()

# %% [markdown]
# ## <span style="color:lightpink">여러 개의 plot을 가지는 subplot생성</span>

# %%
fig,(ax1,ax2)=plt.subplots(nrows=1,ncols=2,figsize=(6,3))

# %% [markdown]
# ## <span style="color:lightpink">plot으로 선 그래프 그리기</span>

# %%
import numpy as np
import pandas as pd

# %%
x_value=[1,2,3,4]
y_value=[2,4,6,8]
plt.plot(x_value,y_value)
plt.show()

# %%
plt.plot(x_value,y_value,color='blue')

# %%
plt.plot(x_value,y_value,color='red',marker='o',linestyle='dashed',linewidth=2,markersize=10)

# %% [markdown]
# ## <span style="color:lightpink">축 명칭 설정, 축의 눈금값 회전, 범례 설정하기</span>

# %%
plt.plot(x_value,y_value,color='red',marker='o',linestyle='dashed',linewidth=2,markersize=10)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %%
x_value=np.arange(0,100)
y_value=2*x_value
plt.plot(x_value,y_value,color='blue')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.xticks(rotation=90)
plt.show()

# %%
x_value=np.arange(0,100)
y_value=2*x_value
plt.plot(x_value,y_value,color='blue')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.xticks(ticks=np.arange(0,105,5),rotation=90)
plt.show()
